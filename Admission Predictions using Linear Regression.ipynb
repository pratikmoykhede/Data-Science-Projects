# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\Pratik2020\\Downloads\\Admission_Predict.csv')
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
df.isna().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  400.000000   400.000000         400.000000  400.000000  400.000000
# mean   316.807500   107.410000           3.087500    3.400000    3.452500
# std     11.473646     6.069514           1.143728    1.006869    0.898478
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   112.000000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit
# count  400.000000  400.000000        400.000000
# mean     8.598925    0.547500          0.724350
# std      0.596317    0.498362          0.142609
# min      6.800000    0.000000          0.340000
# 25%      8.170000    0.000000          0.640000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x='GRE Score',y='Chance of Admit ',data=df)
# Out:
# <AxesSubplot:xlabel='GRE Score', ylabel='Chance of Admit '>

# %%
sns.regplot(x='GRE Score',y='Chance of Admit ',data=df)
# Out:
# <AxesSubplot:xlabel='GRE Score', ylabel='Chance of Admit '>

# %%
sns.scatterplot(x='TOEFL Score',y='Chance of Admit ',data=df)
# Out:
# <AxesSubplot:xlabel='TOEFL Score', ylabel='Chance of Admit '>

# %%
sns.scatterplot(x='University Rating',y='Chance of Admit ',data=df)
# Out:
# <AxesSubplot:xlabel='University Rating', ylabel='Chance of Admit '>

# %%
sns.scatterplot(x='SOP',y='Chance of Admit ',data=df)
# Out:
# <AxesSubplot:xlabel='SOP', ylabel='Chance of Admit '>

# %%
sns.scatterplot(x='LOR ',y='Chance of Admit ',data=df)
# Out:
# <AxesSubplot:xlabel='LOR ', ylabel='Chance of Admit '>

# %%
sns.scatterplot(x='CGPA',y='Chance of Admit ',data=df)
# Out:
# <AxesSubplot:xlabel='CGPA', ylabel='Chance of Admit '>

# %%
sns.scatterplot(x='Research',y='Chance of Admit ',data=df)
# Out:
# <AxesSubplot:xlabel='Research', ylabel='Chance of Admit '>

# %%
df['GRE Score'].value_counts()
# Out:
# 324    19
# 312    19
# 316    14
# 322    14
# 314    14
# 321    13
# 325    13
# 311    12
# 317    12
# 320    12
# 327    12
# 308    11
# 326    11
# 313    11
# 323    10
# 315    10
# 329     9
# 300     9
# 319     9
# 318     9
# 310     8
# 307     8
# 305     8
# 304     8
# 301     8
# 299     8
# 340     8
# 331     8
# 334     7
# 298     7
# 330     6
# 309     6
# 332     6
# 306     6
# 328     6
# 303     5
# 336     5
# 302     5
# 296     5
# 335     4
# 295     4
# 338     4
# 333     4
# 297     4
# 339     3
# 294     2
# 290     2
# 337     1
# 293     1
# Name: GRE Score, dtype: int64

# %%
sns.boxplot(x='GRE Score',data=df)
# Out:
# <AxesSubplot:xlabel='GRE Score'>

# %%
df.dtypes
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
x=df.drop(['Chance of Admit ','Serial No.'],axis=1)
x
y=df[['Chance of Admit ']]
y
# Out:
#      Chance of Admit
# 0                0.92
# 1                0.76
# 2                0.72
# 3                0.80
# 4                0.65
# ..                ...
# 395              0.82
# 396              0.84
# 397              0.91
# 398              0.67
# 399              0.95
#
# [400 rows x 1 columns]

# %%
ax=df['GRE Score'].value_counts().plot(kind='bar',figsize=(10,12))
ax.set_xlabel("GRE SCORE")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df['GRE Score'].value_counts()
# Out:
# 324    19
# 312    19
# 316    14
# 322    14
# 314    14
# 321    13
# 325    13
# 311    12
# 317    12
# 320    12
# 327    12
# 308    11
# 326    11
# 313    11
# 323    10
# 315    10
# 329     9
# 300     9
# 319     9
# 318     9
# 310     8
# 307     8
# 305     8
# 304     8
# 301     8
# 299     8
# 340     8
# 331     8
# 334     7
# 298     7
# 330     6
# 309     6
# 332     6
# 306     6
# 328     6
# 303     5
# 336     5
# 302     5
# 296     5
# 335     4
# 295     4
# 338     4
# 333     4
# 297     4
# 339     3
# 294     2
# 290     2
# 337     1
# 293     1
# Name: GRE Score, dtype: int64

# %%
sns.distplot(x=df["TOEFL Score"])
# Out:
# C:\Users\Pratik2020\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(x=df["GRE Score"])
# Out:
# C:\Users\Pratik2020\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df.drop(['Serial No.'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
sns.violinplot(y='GRE Score',x='University Rating',data=df)
# Out:
# <AxesSubplot:xlabel='University Rating', ylabel='GRE Score'>

# %%
sns.violinplot(y='TOEFL Score',x='University Rating',data=df)
# Out:
# <AxesSubplot:xlabel='University Rating', ylabel='TOEFL Score'>

# %%
sns.barplot(x='Research',y='University Rating',data=df,hue='Research')
# Out:
# <AxesSubplot:xlabel='Research', ylabel='University Rating'>

# %%
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
Lm=LinearRegression()
Lm.fit(x_train,y_train)
y_test_pred=Lm.predict(x_test)
y_train_pred=Lm.predict(x_train)
print(Lm.score(x_test,y_test),Lm.score(x_train,y_train))

print(y_test[0:5])
print(y_pred[0:5])
# Out:
# 0.7456624883029341 0.8221063439698573
#      Chance of Admit
# 132              0.71
# 309              0.70
# 341              0.79
# 196              0.73
# 246              0.72
# [[0.69175175]
#  [0.69339461]
#  [0.77820827]
#  [0.61977251]
#  [0.72309583]]

# %%
from sklearn.metrics import r2_score
print('R2 for test',r2_score(y_test,y_test_pred))
print('R2 for train',r2_score(y_train,y_train_pred))
# Out:
# R2 for test 0.7456624883029341
# R2 for train 0.8221063439698573

# %%
Lm.predict([[290,90,4,4.5,4.5,9.65,0]])
# Out:
# array([[0.77907642]])

# %%
ax1=sns.distplot(y_test,hist=False,color='red',label='Actual')
sns.distplot(y_test_pred,hist=False,color='blue',label='Predicted',ax=ax1)
# Out:
# C:\Users\Pratik2020\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Pratik2020\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>
