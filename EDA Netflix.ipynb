# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Pratik2020\\Desktop\\Datasets\\netflix_titles.csv")

# %%
df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
df.drop(['show_id'],axis=1,inplace=True)

# %%
df
# Out:
#          type                                        title  \
# 0       Movie      Norm of the North: King Sized Adventure
# 1       Movie                   Jandino: Whatever it Takes
# 2     TV Show                           Transformers Prime
# 3     TV Show             Transformers: Robots in Disguise
# 4       Movie                                 #realityhigh
# ...       ...                                          ...
# 6229  TV Show                                 Red vs. Blue
# 6230  TV Show                                        Maron
# 6231    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4             Fernando Lebrija
# ...                        ...
# ...

# %%
df.describe(include='all')
# Out:
#          type   title                director                cast  \
# count    6234    6234                    4265                5664
# unique      2    6172                    3301                5469
# top     Movie  Tunnel  Raúl Campos, Jan Suter  David Attenborough
# freq     4265       3                      18                  18
# mean      NaN     NaN                     NaN                 NaN
# std       NaN     NaN                     NaN                 NaN
# min       NaN     NaN                     NaN                 NaN
# 25%       NaN     NaN                     NaN                 NaN
# 50%       NaN     NaN                     NaN                 NaN
# 75%       NaN     NaN                     NaN                 NaN
# max       NaN     NaN                     NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# count            5758             6223    6234.00000   6224      6234
# ...

# %%
df.isna().sum()
# Out:
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df['date_added']=pd.to_datetime(df['date_added'])

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.countplot(x=df['release_year'],hue='type',data=df)
sns.set(rc={'figure.figsize':(20,10)})

# %%
b=df['type'].value_counts()
sns.barplot(x=b.index,y=b.values)
plt.title('Movies and TV Shows comparison ')
# Out:
# Text(0.5, 1.0, 'Movies and TV Shows comparison ')

# %%
sns.countplot(x='rating',hue='type',data=df)
plt.title('Rating Count ')
# Out:
# Text(0.5, 1.0, 'Rating Count ')

# %%
all_dur = df["duration"].value_counts().head(10)
sns.barplot(x = all_dur.values, y = all_dur.index)
plt.title('Duration count for dataset')
# Out:
# Text(0.5, 1.0, 'Duration count for dataset')

# %%
ry_n=df['release_year'].value_counts()
ry_n
sns.lineplot(x=ry_n.index,y=ry_n.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### After 2000

# %%
ry=df[df['release_year']>2000]
ry
# Out:
#          type                                        title  \
# 0       Movie      Norm of the North: King Sized Adventure
# 1       Movie                   Jandino: Whatever it Takes
# 2     TV Show                           Transformers Prime
# 3     TV Show             Transformers: Robots in Disguise
# 4       Movie                                 #realityhigh
# ...       ...                                          ...
# 6229  TV Show                                 Red vs. Blue
# 6230  TV Show                                        Maron
# 6231    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4             Fernando Lebrija
# ...                        ...
# ...

# %%
ry.groupby('release_year')['type'].value_counts()
# Out:
# release_year  type
# 2001          Movie       30
#               TV Show      4
# 2002          Movie       35
#               TV Show      3
# 2003          Movie       35
#               TV Show      8
# 2004          Movie       40
#               TV Show      9
# 2005          Movie       51
#               TV Show     12
# 2006          Movie       59
#               TV Show      9
# 2007          Movie       60
#               TV Show     11
# 2008          Movie       87
#               TV Show     20
# 2009          Movie       87
#               TV Show     34
# 2010          Movie      111
#               TV Show     38
# 2011          Movie      100
#               TV Show     36
# 2012          Movie      125
#               TV Show     58
# 2013          Movie      177
#               TV Show     60
# 2014          Movie      213
#               TV Show     75
# 2015          Movie      363
#               TV Show    154
# 2016          Movie      593
# ...

# %%
sns.countplot(x=ry['release_year'],hue='type',data=df)
sns.set(rc={'figure.figsize':(20,10)})

# %%
ry['type'].value_counts()
# Out:
# Movie      3900
# TV Show    1924
# Name: type, dtype: int64

# %%
ry['type'].value_counts().sum()
# Out:
# 5824

# %%
Movie_Percentage=(ry['type'].value_counts()[0]/ry['type'].value_counts().sum())*100
print('Movie_Percentage after 2000',Movie_Percentage)
TVShow_Perentage=(ry['type'].value_counts()[1]/ry['type'].value_counts().sum())*100
print('TVShow_Perentage after 2000',TVShow_Perentage)
# Out:
# Movie_Percentage after 2000 66.96428571428571
# TVShow_Perentage after 2000 33.035714285714285

# %%
sns.barplot(x=ry['type'].value_counts().index,y=ry['type'].value_counts().values)
#plt.title('TV shows and Movies released after 2020')
# Out:
# <AxesSubplot:>

# %%
ry['country'].value_counts().head(10)
# Out:
# United States     1840
# India              704
# United Kingdom     330
# Japan              168
# Canada             139
# South Korea        136
# Spain              117
# France              89
# Turkey              79
# Mexico              79
# Name: country, dtype: int64

# %%
sns.barplot(x=ry['country'].value_counts().head(10).index,y=ry['country'].value_counts().head(10).values)
plt.title('Tv shows and movies released after 2000')
# Out:
# Text(0.5, 1.0, 'Tv shows and movies released after 2000')

# %%
sns.barplot(x=ry['rating'].value_counts().head(10).index,y=ry['rating'].value_counts().head(10).values)
plt.plot('Content ratings after 2000')

# %% [markdown]
# ### Before 2000

# %%
ry1=df[df['release_year']<2000]
ry1
# Out:
#          type                           title         director  \
# 167     Movie                        The Bund              NaN
# 201     Movie            Five Elements Ninjas       Cheh Chang
# 301     Movie                    Dante's Peak  Roger Donaldson
# 320     Movie                         Stripes     Ivan Reitman
# 326     Movie                       The Saint    Phillip Noyce
# ...       ...                             ...              ...
# 6028  TV Show      Star Trek: Deep Space Nine              NaN
# 6029  TV Show             Big Bad Beetleborgs              NaN
# 6032  TV Show                   V.R. Troopers              NaN
# 6094  TV Show             Pee-wee's Playhouse              NaN
# 6203  TV Show  Star Trek: The Next Generation              NaN
#
#                                                    cast  \
# 167                                        Chow Yun Fat
# 201   Tien-chi Cheng, Tien Hsiang Lung, Meng Lo, Mic...
# ...

# %%
sns.countplot(x=ry1['release_year'],hue='type',data=ry1)
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='count'>

# %%
sns.barplot(x=ry1['type'].value_counts().values,y=ry1['type'].value_counts().index)
plt.title('Tv Shows and Movies released before 2000')
# Out:
# Text(0.5, 1.0, 'Tv Shows and Movies released before 2000')

# %%
ry1['type'].value_counts()
# Out:
# Movie      337
# TV Show     42
# Name: type, dtype: int64

# %%
Movie_Percentage=(ry1['type'].value_counts()[0]/ry1['type'].value_counts().sum())*100
print('Movie_Percentage before 2000',Movie_Percentage)
TVShow_Perentage=(ry1['type'].value_counts()[1]/ry1['type'].value_counts().sum())*100
print('TVShow_Perentage before 2000',TVShow_Perentage)
# Out:
# Movie_Percentage before 2000 88.91820580474933
# TVShow_Perentage before 2000 11.081794195250659

# %%
ry1['country'].value_counts().head(10)
# Out:
# United States                    177
# India                             66
# Hong Kong                         29
# United Kingdom                    17
# United Kingdom, United States     11
# Poland                             7
# Japan                              7
# United States, France, Japan       5
# Australia                          4
# Mexico                             4
# Name: country, dtype: int64

# %%
sns.barplot(x=ry1['country'].value_counts().head(10).index,y=ry1['country'].value_counts().head(10).values)

plt.title('Country wise tv show and movies count before 2000')
# Out:
# Text(0.5, 1.0, 'Country wise tv show and movies count before 2000')

# %%
sns.barplot(x=ry1['rating'].value_counts().head(10).index,y=ry1['rating'].value_counts().head(10).values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### India

# %%
india=ry[ry['country']=='India']
india1=india['type'].value_counts()
india1
india1=india1.reset_index()
india1
plt.pie(x=india1['type'],labels=india1['index'],autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2a7d9841f40>,
# ...
#  [Text(-1.0693773239567956, 0.25774432875817616, 'Movie'),
#   Text(1.0693773480885567, -0.2577442286358438, 'TV Show')],
#  [Text(-0.583296722158252, 0.14058781568627787, '92%'),
#   Text(0.5832967353210309, -0.1405877610740966, '8%')])

# %%
india2=ry1[ry1['country']=='India']
india2
india3=india2['type'].value_counts()
india3=india3.reset_index()
plt.pie(x=india3['type'],labels=india3['index'],autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2a7d9b63160>],
#  [Text(-1.1, 1.3471114790620887e-16, 'Movie')],
#  [Text(-0.6, 7.347880794884119e-17, '100%')])

# %%
sns.countplot(x=df[df['country']=='India']['type'],hue='type',data=df[df['country']=='India'])
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
ind4=df[df['country']=='India']
ind5=ind['rating'].value_counts()
ind5
ind5=ind5.reset_index()
plt.pie(x=ind5['rating'],labels=ind5['index'],autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2a7d9d355b0>,
# ...
#  [Text(-0.14413004198978094, 1.0905166349011024, 'TV-14'),
#   Text(-0.5955549076385406, -0.9248320669114202, 'TV-MA'),
#   Text(0.6996574974640838, -0.8488105714718073, 'TV-PG'),
#   Text(1.057469571083546, -0.30291600524300677, 'NR'),
#   Text(1.0834170116770645, -0.19028289152926955, 'TV-G'),
#   Text(1.0913707164956414, -0.13751348725048895, 'TV-Y7'),
#   Text(1.0956511060652425, -0.09771721331480378, 'PG-13'),
#   Text(1.0979775911452583, -0.06667240315795, 'PG'),
#   Text(1.0991009993930907, -0.04446339093129846, 'R'),
#   Text(1.0996763321868686, -0.026682661562070775, 'TV-Y7-FV'),
#   Text(1.0999190804607115, -0.01334228010736129, 'TV-Y'),
#   Text(1.0999910090155927, -0.00444748073168981, 'UR')],
#  [Text(-0.07861638653988051, 0.5948272554006012, '54%'),
#   Text(-0.3248481314392039, -0.5044538546789564, '23%'),
#   Text(0.38163136225313654, -0.46298758443916754, '17%'),
# ...

# %%
sns.barplot(x=df['rating'].value_counts().head(10).index,y=df['rating'].value_counts().head(10).values)
# Out:
# <AxesSubplot:>

# %%
new_india=ry[ry['country']=='India']
new_india
# Out:
#          type                                              title  \
# 35      Movie                                         Article 15
# 37      Movie                              Ee Nagaraniki Emaindi
# 41      Movie                                                 PK
# 58      Movie                                           Watchman
# 99    TV Show                                      Bard of Blood
# ...       ...                                                ...
# 5573    Movie  The Human Factor: The Untold Story of the Bomb...
# 5708  TV Show                                      Little Things
# 5839  TV Show                             The House That Made Me
# 5867  TV Show                                   Sab Jholmaal Hai
# 5923  TV Show                                Pyaar Tune Kya Kiya
#
#                      director  \
# 35              Anubhav Sinha
# 37            Tharun Bhascker
# 41            Rajkumar Hirani
# 58                A. L. Vijay
# ...

# %%
sns.barplot(x=new_india['rating'].value_counts().head(10).index,y=new_india['rating'].value_counts().head(10).values)
# Out:
# <AxesSubplot:>

# %%
old_india=ry1[ry1['country']=='India']
old_india
# Out:
#        type                           title           director  \
# 358   Movie                  Aakhri Adaalat        Rajiv Mehra
# 364   Movie           Chadi Jawani Budhe Nu                NaN
# 366   Movie                Ek Jaan Hain Hum        Rajiv Mehra
# 374   Movie                     Khoon Khoon   Mohammed Hussain
# 379   Movie                      Manoranjan      Shammi Kapoor
# ...     ...                             ...                ...
# 4232  Movie               The Great Gambler     Shakti Samanta
# 4237  Movie  Trikal (Past, Present, Future)      Shyam Benegal
# 5510  Movie                         Barsaat  Rajkumar Santoshi
# 5557  Movie                           Elaan        K. Ramanlal
# 5568  Movie                       Salaakhen          A. Salaam
#
#                                                    cast country date_added  \
# 358   Vinod Khanna, Dimple Kapadia, Jackie Shroff, S...   India 2017-09-01
# ...

# %%
sns.barplot(x=old_india['rating'].value_counts().head(10).index,y=old_india['rating'].value_counts().head(10).values)
# Out:
# <AxesSubplot:>

# %%
movie=df[df['type']=='Movie']
movie['type'].value_counts().sort_values(ascending=False)
# Out:
# Movie    4265
# Name: type, dtype: int64

# %%
old_movie=ry1[ry1['type']=='Movie']
old_movie
# Out:
#        type                          title             director  \
# 167   Movie                       The Bund                  NaN
# 201   Movie           Five Elements Ninjas           Cheh Chang
# 301   Movie                   Dante's Peak      Roger Donaldson
# 320   Movie                        Stripes         Ivan Reitman
# 326   Movie                      The Saint        Phillip Noyce
# ...     ...                            ...                  ...
# 5516  Movie                            Dad  Gary David Goldberg
# 5524  Movie  How to Make an American Quilt    Jocelyn Moorhouse
# 5541  Movie               Schindler's List     Steven Spielberg
# 5557  Movie                          Elaan          K. Ramanlal
# 5568  Movie                      Salaakhen            A. Salaam
#
#                                                    cast        country  \
# 167                                        Chow Yun Fat      Hong Kong
# ...

# %%
ry1_dur=ry1['duration'].value_counts().head(10)
ry1_dur
sns.barplot(x=ry1_dur.index,y=ry1_dur.values)
# Out:
# <AxesSubplot:>

# %%
ry_dur=ry['duration'].value_counts().head(10)
ry_dur
sns.barplot(x=ry_dur.index,y=ry_dur.values)
# Out:
# <AxesSubplot:>

# %%
p=ry1[ry1['type']=='Movie']
p
# Out:
#        type                          title             director  \
# 167   Movie                       The Bund                  NaN
# 201   Movie           Five Elements Ninjas           Cheh Chang
# 301   Movie                   Dante's Peak      Roger Donaldson
# 320   Movie                        Stripes         Ivan Reitman
# 326   Movie                      The Saint        Phillip Noyce
# ...     ...                            ...                  ...
# 5516  Movie                            Dad  Gary David Goldberg
# 5524  Movie  How to Make an American Quilt    Jocelyn Moorhouse
# 5541  Movie               Schindler's List     Steven Spielberg
# 5557  Movie                          Elaan          K. Ramanlal
# 5568  Movie                      Salaakhen            A. Salaam
#
#                                                    cast        country  \
# 167                                        Chow Yun Fat      Hong Kong
# ...

# %%
p['type'].value_counts()
# Out:
# Movie    337
# Name: type, dtype: int64

# %%
p['movie_duration_min']=p['duration'].str.replace('min','')
# Out:
# <ipython-input-679-9ecd63b54831>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p['movie_duration_min']=p['duration'].str.replace('min','')

# %%
p
# Out:
#        type                          title             director  \
# 167   Movie                       The Bund                  NaN
# 201   Movie           Five Elements Ninjas           Cheh Chang
# 301   Movie                   Dante's Peak      Roger Donaldson
# 320   Movie                        Stripes         Ivan Reitman
# 326   Movie                      The Saint        Phillip Noyce
# ...     ...                            ...                  ...
# 5516  Movie                            Dad  Gary David Goldberg
# 5524  Movie  How to Make an American Quilt    Jocelyn Moorhouse
# 5541  Movie               Schindler's List     Steven Spielberg
# 5557  Movie                          Elaan          K. Ramanlal
# 5568  Movie                      Salaakhen            A. Salaam
#
#                                                    cast        country  \
# 167                                        Chow Yun Fat      Hong Kong
# ...

# %%
p.drop('duration',axis=1,inplace=True)
# Out:
# C:\Users\Pratik2020\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
p
# Out:
#        type                          title             director  \
# 167   Movie                       The Bund                  NaN
# 201   Movie           Five Elements Ninjas           Cheh Chang
# 301   Movie                   Dante's Peak      Roger Donaldson
# 320   Movie                        Stripes         Ivan Reitman
# 326   Movie                      The Saint        Phillip Noyce
# ...     ...                            ...                  ...
# 5516  Movie                            Dad  Gary David Goldberg
# 5524  Movie  How to Make an American Quilt    Jocelyn Moorhouse
# 5541  Movie               Schindler's List     Steven Spielberg
# 5557  Movie                          Elaan          K. Ramanlal
# 5568  Movie                      Salaakhen            A. Salaam
#
#                                                    cast        country  \
# 167                                        Chow Yun Fat      Hong Kong
# ...

# %%
p['movie_duration_min'].astype('float').mean(axis=0)
# Out:
# 110.7893175074184

# %%
q=ry[ry['type']=='Movie']
q
# Out:
#        type                                    title  \
# 0     Movie  Norm of the North: King Sized Adventure
# 1     Movie               Jandino: Whatever it Takes
# 4     Movie                             #realityhigh
# 6     Movie                                 Automata
# 7     Movie       Fabrizio Copano: Solo pienso en mi
# ...     ...                                      ...
# 5577  Movie                          Frank and Cindy
# 5578  Movie                          Frank and Cindy
# 5579  Movie                                  Iverson
# 5580  Movie      Jeremy Scott: The People's Designer
# 6231  Movie   Little Baby Bum: Nursery Rhyme Friends
#
#                              director  \
# 0            Richard Finn, Tim Maltby
# 1                                 NaN
# 4                    Fernando Lebrija
# 6                         Gabe Ibáñez
# 7     Rodrigo Toro, Francisco Schultz
# ...                               ...
# 5577                 G.J. Echternkamp
# ...

# %%
q['movie_duration_min']=q['duration'].str.replace('min','')
# Out:
# <ipython-input-685-2f330c9e37f1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q['movie_duration_min']=q['duration'].str.replace('min','')

# %%
q
# Out:
#        type                                    title  \
# 0     Movie  Norm of the North: King Sized Adventure
# 1     Movie               Jandino: Whatever it Takes
# 4     Movie                             #realityhigh
# 6     Movie                                 Automata
# 7     Movie       Fabrizio Copano: Solo pienso en mi
# ...     ...                                      ...
# 5577  Movie                          Frank and Cindy
# 5578  Movie                          Frank and Cindy
# 5579  Movie                                  Iverson
# 5580  Movie      Jeremy Scott: The People's Designer
# 6231  Movie   Little Baby Bum: Nursery Rhyme Friends
#
#                              director  \
# 0            Richard Finn, Tim Maltby
# 1                                 NaN
# 4                    Fernando Lebrija
# 6                         Gabe Ibáñez
# 7     Rodrigo Toro, Francisco Schultz
# ...                               ...
# 5577                 G.J. Echternkamp
# ...

# %%
q.drop('duration',axis=1,inplace=True)
# Out:
# C:\Users\Pratik2020\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
q
# Out:
#        type                                    title  \
# 0     Movie  Norm of the North: King Sized Adventure
# 1     Movie               Jandino: Whatever it Takes
# 4     Movie                             #realityhigh
# 6     Movie                                 Automata
# 7     Movie       Fabrizio Copano: Solo pienso en mi
# ...     ...                                      ...
# 5577  Movie                          Frank and Cindy
# 5578  Movie                          Frank and Cindy
# 5579  Movie                                  Iverson
# 5580  Movie      Jeremy Scott: The People's Designer
# 6231  Movie   Little Baby Bum: Nursery Rhyme Friends
#
#                              director  \
# 0            Richard Finn, Tim Maltby
# 1                                 NaN
# 4                    Fernando Lebrija
# 6                         Gabe Ibáñez
# 7     Rodrigo Toro, Francisco Schultz
# ...                               ...
# 5577                 G.J. Echternkamp
# ...

# %%
q['movie_duration_min'].astype('float').mean(axis=0)
# Out:
# 97.99666666666667

# %% [markdown]
# # Observations
# ####  In dataset there are more movies released than tv shows
# ####  Most common rating - TV-MA
# ####  In 2020-least number of release
# ####  2019 is the only year in which there are more TV Shows released than movies
# ####  After 2000-
#     In 2017 -most no of movies in 20 years (Between 2000-2020 year)
# 	In 2019 - most number of tv shows (Between 2000-2020 year)
#     Almost double the release of movies than tv show
#     Most released are in USA,India and UK( ascending order)
#     content of Tv-MA ratings are more
# ####  Before 2020-
#     Movies released 88%
#     Tv released 12%
#     Most released are in USA,India and Hongkong( ascending order)
#
# #### India -
#     Movie released - 92%
#     Tv Shows released - 8%
#     Before 2000 No Tv show was released
#     for india ratings 54%-tv 14
# 	least ratings -TV Y
# #### India after 2000-
#     Tv -14    most rating
#     tv-y7-fv Least rating
# #### before 2000
#     tv 14 most-Most ratings
#     tv g least-Least Ratings
#     many rating cateogries are introduced after 2000
#
# #### Avg movie duration before 2000
# 110 min
#
# #### Avg movie duration after 2000
# 98 min
