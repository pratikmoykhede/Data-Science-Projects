# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df7=pd.read_csv('C:\\Users\\Pratik2020\\Downloads\\HR Analytics.csv')
df7
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df8=df7[:]

# %%
df8
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df8.drop(['city','city_development_index'],inplace=True,axis=1)
# Out:
# C:\Users\Pratik2020\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df8
# Out:
#        enrollee_id gender      relevent_experience enrolled_university  \
# 0             8949   Male  Has relevent experience       no_enrollment
# 1            29725   Male   No relevent experience       no_enrollment
# 2            11561    NaN   No relevent experience    Full time course
# 3            33241    NaN   No relevent experience                 NaN
# 4              666   Male  Has relevent experience       no_enrollment
# ...            ...    ...                      ...                 ...
# 19153         7386   Male   No relevent experience       no_enrollment
# 19154        31398   Male  Has relevent experience       no_enrollment
# 19155        24576   Male  Has relevent experience       no_enrollment
# 19156         5756   Male  Has relevent experience       no_enrollment
# 19157        23834    NaN   No relevent experience       no_enrollment
#
#       education_level major_discipline experience company_size  \
# ...

# %%
df8['gender'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x=df8['gender'],hue='target',data=df8)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
plt.pie(x=df8['gender'].value_counts(),labels=df8['gender'].value_counts().index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2143924a700>,
# ...
#  [Text(-1.048755143841177, 0.3318322592314862, 'Male'),
#   Text(1.0342879850246178, -0.37449748201251787, 'Female'),
#   Text(1.0990774479951975, -0.04504179512812524, 'Other')],
#  [Text(-0.5720482602770056, 0.1809994141262652, '90.2%'),
#   Text(0.5641570827407006, -0.20427135382500972, '8.5%'),
#   Text(0.5994967898155622, -0.02456825188806831, '1.3%')])

# %%
df8_M=df8[df8['gender']=='Male']
df9=df8_M['target'].value_counts()
df9=df9.reset_index()
plt.pie(x=df9['target'],labels=df9['target'].index,shadow=True,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21439235310>,
# ...
#  [Text(-0.8300862044132027, 0.7217734362269665, '0'),
#   Text(0.8300862044132021, -0.7217734362269671, '1')],
#  [Text(-0.45277429331629226, 0.39369460157834535, '77.2%'),
#   Text(0.45277429331629204, -0.3936946015783456, '22.8%')])

# %%
df8_F=df8[df8['gender']=='Female']
df9=df8_F['target'].value_counts()
df9=df9.reset_index()
plt.pie(x=df9['target'],labels=df9['target'].index,shadow=True,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21427089340>,
# ...
#  [Text(-0.7445772447302497, 0.809694217979794, '0'),
#   Text(0.7445772447302491, -0.8096942179797944, '1')],
#  [Text(-0.4061330425801361, 0.4416513916253421, '73.7%'),
#   Text(0.4061330425801359, -0.44165139162534234, '26.3%')])

# %%
sns.countplot(x=df8['relevent_experience'],data=df8,hue='target')
# Out:
# <AxesSubplot:xlabel='relevent_experience', ylabel='count'>

# %%
df8_R=df8_M[df8_M['relevent_experience']=='Has relevent experience']
df9=df8_R['target'].value_counts()
df9=df9.reset_index()
df9
plt.pie(x=df9['target'],labels=df9['index'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2142a377c40>,
# ...
#  [Text(-0.8945882020496034, 0.6400874539886391, '0.0'),
#   Text(0.894588232014259, -0.6400874121099419, '1.0')],
#  [Text(-0.4879572011179655, 0.34913861126653034, '80.2%'),
#   Text(0.487957217462323, -0.3491385884236047, '19.8%')])

# %%
df8_NR=df8_M[df8_M['relevent_experience']=='No relevent experience']
df8_R
df9=df8_NR['target'].value_counts()
df9=df9.reset_index()
plt.pie(x=df9['target'],labels=df9['index'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21429359e50>,
# ...
#  [Text(-0.5904096786947242, 0.9281252131601602, '0.0'),
#   Text(0.5904096786947237, -0.9281252131601605, '1.0')],
#  [Text(-0.32204164292439497, 0.5062501162691782, '68.0%'),
#   Text(0.3220416429243947, -0.5062501162691784, '32.0%')])

# %%
df8_NR=df8_M[df8_M['relevent_experience']=='No relevent experience']
df9=df8_NR['target'].value_counts()
df9=df9.reset_index()
plt.pie(x=df9['target'],labels=df9['index'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2142a074f40>,
# ...
#  [Text(-0.5904096786947242, 0.9281252131601602, '0.0'),
#   Text(0.5904096786947237, -0.9281252131601605, '1.0')],
#  [Text(-0.32204164292439497, 0.5062501162691782, '68.0%'),
#   Text(0.3220416429243947, -0.5062501162691784, '32.0%')])

# %%
df8_NR=df8_F[df8_F['relevent_experience']=='No relevent experience']
df9=df8_NR['target'].value_counts()
df9=df9.reset_index()
plt.pie(x=df9['target'],labels=df9['index'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x214292993d0>,
# ...
#  [Text(-0.40896122772486687, 1.021151660733003, '0.0'),
#   Text(0.4089613233319836, -1.0211516224432848, '1.0')],
#  [Text(-0.2230697605772001, 0.5569918149452743, '62.1%'),
#   Text(0.22306981272653648, -0.5569917940599735, '37.9%')])

# %%
df8_NR=df8[df8['enrolled_university']=='no_enrollment']
df9=df8_NR['target'].value_counts()
df9=df9.reset_index()
plt.pie(x=df9['target'],labels=df9['index'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2142931f970>,
# ...
#  [Text(-0.8661835674547197, 0.6780309930021011, '0.0'),
#   Text(0.8661835991956403, -0.6780309524531212, '1.0')],
#  [Text(-0.4724637640662107, 0.3698350870920551, '78.9%'),
#   Text(0.47246378137944006, -0.3698350649744297, '21.1%')])

# %%
df8.columns
# Out:
# Index(['enrollee_id', 'gender', 'relevent_experience', 'enrolled_university',
#        'education_level', 'major_discipline', 'experience', 'company_size',
#        'company_type', 'last_new_job', 'training_hours', 'target'],
#       dtype='object')

# %%
sns.barplot(x=df8['education_level'].value_counts().index,y=df8['education_level'].value_counts())
# Out:
# <AxesSubplot:ylabel='education_level'>

# %%
df8['education_level'].isna().sum()
# Out:
# 460

# %%
sns.countplot(x='relevent_experience',data=df8,hue='target')
# Out:
# <AxesSubplot:xlabel='relevent_experience', ylabel='count'>

# %%
sns.countplot(x=df8['major_discipline'],data=df8,hue='target')
# Out:
# <AxesSubplot:xlabel='major_discipline', ylabel='count'>

# %%
sns.barplot(x=df8['major_discipline'].value_counts().index,y=df8['major_discipline'].value_counts())
# Out:
# <AxesSubplot:ylabel='major_discipline'>

# %%
df8['major_discipline'].isna().sum()
# Out:
# 2813

# %%
df8['major_discipline'].fillna('Na',inplace=True)
sns.barplot(x=df8['major_discipline'].value_counts().index,y=df8['major_discipline'].value_counts())
# Out:
# C:\Users\Pratik2020\anaconda3\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# <AxesSubplot:ylabel='major_discipline'>

# %%
df8
# Out:
#        enrollee_id gender      relevent_experience enrolled_university  \
# 0             8949   Male  Has relevent experience       no_enrollment
# 1            29725   Male   No relevent experience       no_enrollment
# 2            11561    NaN   No relevent experience    Full time course
# 3            33241    NaN   No relevent experience                 NaN
# 4              666   Male  Has relevent experience       no_enrollment
# ...            ...    ...                      ...                 ...
# 19153         7386   Male   No relevent experience       no_enrollment
# 19154        31398   Male  Has relevent experience       no_enrollment
# 19155        24576   Male  Has relevent experience       no_enrollment
# 19156         5756   Male  Has relevent experience       no_enrollment
# 19157        23834    NaN   No relevent experience       no_enrollment
#
#       education_level major_discipline experience company_size  \
# ...

# %%
plt.pie(x=df8['experience'].value_counts(),labels=df8['experience'].value_counts().index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2142655d040>,
# ...
#  [Text(0.9430926846212612, 0.5661944791446332, '>20'),
#   Text(0.2765486075058483, 1.0646693701269783, '5'),
#   Text(-0.2314698115813275, 1.0753705065355406, '4'),
#   Text(-0.6793301481492854, 0.865165041951806, '3'),
#   Text(-0.9745381122765342, 0.5101719981736447, '6'),
#   Text(-1.0948556549934891, 0.10625956299918796, '2'),
#   Text(-1.0636382573232384, -0.2804882485210115, '7'),
#   Text(-0.9146103009763745, -0.6111366437613651, '10'),
#   Text(-0.6730487723881475, -0.8700605438627864, '9'),
#   Text(-0.392849797489371, -1.0274575595189128, '8'),
#   Text(-0.13207895435917558, -1.0920417344659439, '15'),
#   Text(0.11175272160712751, -1.0943086078494493, '11'),
#   Text(0.33288787092598493, -1.0484205575008365, '14'),
#   Text(0.5217609182851993, -0.9683829532525786, '1'),
#   Text(0.6834507111603606, -0.8619136415061531, '<1'),
#   Text(0.8190358814978566, -0.734288924619614, '16'),
# ...

# %%
sns.barplot(x=df8['company_size'].value_counts().index,y=df8['company_size'].value_counts())
# Out:
# <AxesSubplot:ylabel='company_size'>

# %%
sns.countplot(x=df8['company_size'],hue='target',data=df8)
# Out:
# <AxesSubplot:xlabel='company_size', ylabel='count'>

# %%
df8['training_hours'].value_counts()
# Out:
# 28     329
# 12     292
# 18     291
# 22     282
# 50     279
#       ...
# 266      6
# 272      5
# 234      5
# 286      5
# 238      4
# Name: training_hours, Length: 241, dtype: int64

# %%
df8.groupby('training_hours')['target'].value_counts()
# Out:
# training_hours  target
# 1               0.0        7
#                 1.0        2
# 2               0.0       71
#                 1.0       25
# 3               0.0       87
#                           ..
# 332             1.0        4
# 334             0.0        9
#                 1.0        2
# 336             0.0        8
#                 1.0        3
# Name: target, Length: 474, dtype: int64

# %%
to_LabelEncode = df7[['gender', 'relevent_experience',
       'enrolled_university', 'education_level', 'major_discipline',
       'experience', 'company_size', 'company_type', 'last_new_job']]

le = LabelEncoder()
train_temp = to_LabelEncode.astype("str").apply(le.fit_transform)
train_final = train_temp.where(~to_LabelEncode.isna(),to_LabelEncode)

# %%
df7.drop(['gender', 'relevent_experience',
       'enrolled_university', 'education_level', 'major_discipline',
       'experience', 'company_size', 'company_type', 'last_new_job'],inplace=True,axis=1)

# %%
dff=train_final.join(df7)
dff
# Out:
#       gender  relevent_experience enrolled_university education_level  \
# 0          1                    0                   3               0
# 1          1                    1                   3               0
# 2        NaN                    1                   0               0
# 3        NaN                    1                 NaN               0
# 4          1                    0                   3               2
# ...      ...                  ...                 ...             ...
# 19153      1                    1                   3               0
# 19154      1                    0                   3               0
# 19155      1                    0                   3               0
# 19156      1                    0                   3               1
# 19157    NaN                    1                   3               4
#
#       major_discipline experience company_size company_type last_new_job  \
# ...

# %%
dff.drop(['city','enrollee_id'],axis=1,inplace=True)

# %%
dff1=dff[:]

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression

lr= LinearRegression()

imputer = IterativeImputer(random_state=42, estimator=lr, max_iter=10, n_nearest_features=2, imputation_order = 'roman')
df_final = imputer.fit_transform(dff.drop('target', axis=1))

df_final = pd.DataFrame(df_final, columns = dff.drop('target', axis=1).columns)
df_final
# Out:
# C:\Users\Pratik2020\anaconda3\lib\site-packages\sklearn\impute\_iterative.py:685: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn("[IterativeImputer] Early stopping criterion not"
#          gender  relevent_experience  enrolled_university  education_level  \
# 0      1.000000                  0.0             3.000000              0.0
# 1      1.000000                  1.0             3.000000              0.0
# 2      0.940903                  1.0             0.000000              0.0
# 3      0.857791                  1.0             2.487906              0.0
# 4      1.000000                  0.0             3.000000              2.0
# ...         ...                  ...                  ...              ...
# 19153  1.000000                  1.0             3.000000              0.0
# 19154  1.000000                  0.0             3.000000              0.0
# ...

# %%
df_final.isna().sum()
# Out:
# gender                    0
# relevent_experience       0
# enrolled_university       0
# education_level           0
# major_discipline          0
# experience                0
# company_size              0
# company_type              0
# last_new_job              0
# city_development_index    0
# training_hours            0
# dtype: int64

# %%
x=df_final
x
# Out:
#          gender  relevent_experience  enrolled_university  education_level  \
# 0      1.000000                  0.0             3.000000              0.0
# 1      1.000000                  1.0             3.000000              0.0
# 2      0.940903                  1.0             0.000000              0.0
# 3      0.857791                  1.0             2.487906              0.0
# 4      1.000000                  0.0             3.000000              2.0
# ...         ...                  ...                  ...              ...
# 19153  1.000000                  1.0             3.000000              0.0
# 19154  1.000000                  0.0             3.000000              0.0
# 19155  1.000000                  0.0             3.000000              0.0
# 19156  1.000000                  0.0             3.000000              1.0
# 19157  0.926300                  1.0             3.000000              4.0
#
# ...

# %%
y=dff[['target']]
y
# Out:
#        target
# 0         1.0
# 1         0.0
# 2         0.0
# 3         1.0
# 4         0.0
# ...       ...
# 19153     1.0
# 19154     1.0
# 19155     0.0
# 19156     0.0
# 19157     0.0
#
# [19158 rows x 1 columns]

# %%
y.value_counts()
# Out:
# target
# 0.0       14381
# 1.0        4777
# dtype: int64

# %% [markdown]
# ### Oversampling

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
Ro=RandomOverSampler(sampling_strategy=1)
x_new,y_new=Ro.fit_resample(x,y)
x_new.shape,y_new.shape
# Out:
# ((28762, 11), (28762, 1))

# %% [markdown]
# ### Train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.4,random_state=1)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
Lr=LogisticRegression()
Lr.fit(x_train,y_train)
y_test_pred=Lr.predict(x_test)
y_train_pred=Lr.predict(x_train)
# Out:
# C:\Users\Pratik2020\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\Pratik2020\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import *

# %%
lr_acc=accuracy_score(y_test, y_test_pred)
print("Accuracy Score:-",lr_acc)
print("F1 Score:-", f1_score(y_test,y_test_pred))
print("Average Precision Score:-", average_precision_score(y_test, y_test_pred))
print("Log Loss:-", log_loss(y_test,  y_test_pred))
print("Precision Score:-", precision_score(y_test,  y_test_pred))
print("Recall Score:-", recall_score(y_test,  y_test_pred))
print("ROC-AUC Score:-", roc_auc_score(y_test, y_test_pred))
# Out:
# Accuracy Score:- 0.6658843980877879
# F1 Score:- 0.651685393258427
# Average Precision Score:- 0.6088625784863467
# Log Loss:- 11.540064368986382
# Precision Score:- 0.6750516238032663
# Recall Score:- 0.6298826414433351
# ROC-AUC Score:- 0.6656141985684585

# %%
print(confusion_matrix(y_test,y_test_pred))
# Out:
# [[4065 1731]
#  [2113 3596]]

# %%
from sklearn.model_selection import GridSearchCV
parameters=[{'penalty':['l1','l2'],'C':[0.001,.009,0.01,.09],'random_state':[0,10,20,30,37]}]

grid_search = GridSearchCV(Lr, parameters, scoring='recall', n_jobs=-1, )


result = grid_search.fit(x_train, y_train)

print(result.best_score_)
print(result.best_params_)
# Out:
# C:\Users\Pratik2020\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan 0.51752687
#  0.51752687 0.51752687 0.51752687 0.51752687        nan        nan
#         nan        nan        nan 0.60066798 0.60066798 0.60066798
#  0.60066798 0.60066798        nan        nan        nan        nan
#         nan 0.61196806 0.61196806 0.61196806 0.61196806 0.61196806
#         nan        nan        nan        nan        nan 0.63687671
#  0.63687671 0.63687671 0.63687671 0.63687671]
#   warnings.warn(
# C:\Users\Pratik2020\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 0.6368767055898474
# {'C': 0.09, 'penalty': 'l2', 'random_state': 0}
# ...

# %%
Lr=LogisticRegression(C= 0.09, penalty= 'l2', random_state= 0,class_weight="balanced")
Lr.fit(x_train,y_train)
y_test_pred=Lr.predict(x_test)
y_train_pred=Lr.predict(x_train)
# Out:
# C:\Users\Pratik2020\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\Pratik2020\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
lr_acc=accuracy_score(y_test, y_test_pred)
print("Accuracy Score:-",lr_acc)
print("F1 Score:-", f1_score(y_test,y_test_pred))
print("Average Precision Score:-", average_precision_score(y_test, y_test_pred))
print("Log Loss:-", log_loss(y_test,  y_test_pred))
print("Precision Score:-", precision_score(y_test,  y_test_pred))
print("Recall Score:-", recall_score(y_test,  y_test_pred))
print("ROC-AUC Score:-", roc_auc_score(y_test, y_test_pred))
# Out:
# Accuracy Score:- 0.662755323772273
# F1 Score:- 0.6441672780630961
# Average Precision Score:- 0.606836031980338
# Log Loss:- 11.648135431093305
# Precision Score:- 0.6760346487006738
# Recall Score:- 0.6151690313540025
# ROC-AUC Score:- 0.6623981802732745

# %%
print(confusion_matrix(y_test,y_test_pred))
# Out:
# [[4113 1683]
#  [2197 3512]]

# %%
sns.heatmap(confusion_matrix(y_test,y_test_pred),annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.71      0.68      5796
#          1.0       0.68      0.62      0.64      5709
#
#     accuracy                           0.66     11505
#    macro avg       0.66      0.66      0.66     11505
# weighted avg       0.66      0.66      0.66     11505

# %%
y_pred_new_threshold = (Lr.predict_proba(x_test)[:,1]>=0.6).astype(int)
y_pred_new_threshold
# Out:
# array([0, 1, 0, ..., 1, 0, 0])

# %%
print(confusion_matrix(y_test,y_pred_new_threshold))
# Out:
# [[4992  804]
#  [3456 2253]]

# %%
lr_acc=accuracy_score(y_test, y_pred_new_threshold)
print("Accuracy Score:-",lr_acc)
print("F1 Score:-", f1_score(y_test,y_pred_new_threshold))
print("Average Precision Score:-", average_precision_score(y_test, y_pred_new_threshold))
print("Log Loss:-", log_loss(y_test, y_pred_new_threshold))
print("Precision Score:-", precision_score(y_test,  y_pred_new_threshold))
print("Recall Score:-", recall_score(y_test,  y_pred_new_threshold))
print("ROC-AUC Score:-", roc_auc_score(y_test, y_pred_new_threshold))
# Out:
# Accuracy Score:- 0.6297262059973925
# F1 Score:- 0.5140314852840521
# Average Precision Score:- 0.5912396834270286
# Log Loss:- 12.788859653946403
# Precision Score:- 0.7369970559371933
# Recall Score:- 0.394640042038886
# ROC-AUC Score:- 0.6279618429656127

# %%
print(classification_report(y_test,y_pred_new_threshold))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.86      0.70      5796
#          1.0       0.74      0.39      0.51      5709
#
#     accuracy                           0.63     11505
#    macro avg       0.66      0.63      0.61     11505
# weighted avg       0.66      0.63      0.61     11505

# %% [markdown]
# ### Decision Tree

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %%
dt=tree.DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_dt_pred=dt.predict(x_test)
y_dt_train_pred=dt.predict(x_train)

# %%
lr_acc=accuracy_score(y_test,y_dt_pred )
print("Accuracy Score:-",lr_acc)
print("F1 Score:-", f1_score(y_test,y_dt_pred))
print("Average Precision Score:-", average_precision_score(y_test, y_dt_pred))
print("Log Loss:-", log_loss(y_test, y_dt_pred))
print("Precision Score:-", precision_score(y_test,  y_dt_pred))
print("Recall Score:-", recall_score(y_test,  y_dt_pred))
print("ROC-AUC Score:-", roc_auc_score(y_test, y_dt_pred))
# Out:
# Accuracy Score:- 0.8352020860495437
# F1 Score:- 0.8465025906735751
# Average Precision Score:- 0.7624951986661852
# Log Loss:- 5.692016642773957
# Precision Score:- 0.7869938280897185
# Recall Score:- 0.9157470660360834
# ROC-AUC Score:- 0.835806590298925

# %%
print(confusion_matrix(y_test,y_dt_pred))
# Out:
# [[4381 1415]
#  [ 481 5228]]

# %%
print(classification_report(y_test, y_dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.76      0.82      5796
#          1.0       0.79      0.92      0.85      5709
#
#     accuracy                           0.84     11505
#    macro avg       0.84      0.84      0.83     11505
# weighted avg       0.84      0.84      0.83     11505

# %%
lr_acc=accuracy_score(y_train,y_dt_train_pred)
print("Accuracy Score:-",lr_acc)
print("F1 Score:-", f1_score(y_train,y_dt_train_pred))
print("Average Precision Score:-", average_precision_score(y_train, y_dt_train_pred))
print("Log Loss:-", log_loss(y_train, y_dt_train_pred))
print("Precision Score:-", precision_score(y_train,  y_dt_train_pred))
print("Recall Score:-", recall_score(y_train, y_dt_train_pred))
print("ROC-AUC Score:-", roc_auc_score(y_train, y_dt_train_pred))
# Out:
# Accuracy Score:- 0.9990728400069537
# F1 Score:- 0.9990779160903642
# Average Precision Score:- 0.9983886845856407
# Log Loss:- 0.032023527698194956
# Precision Score:- 0.9986175115207373
# Recall Score:- 0.9995387453874539
# ROC-AUC Score:- 0.9990704792749733

# %%
print(classification_report(y_train,y_dt_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      8585
#          1.0       1.00      1.00      1.00      8672
#
#     accuracy                           1.00     17257
#    macro avg       1.00      1.00      1.00     17257
# weighted avg       1.00      1.00      1.00     17257

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
tree.plot_tree(dt,filled=True)
# Out:
# [Text(588.1669894246528, 536.4473684210526, 'X[7] <= 4.649\ngini = 0.5\nsamples = 17257\nvalue = [8585, 8672]'),
#  Text(267.06175072016595, 522.1421052631579, 'X[7] <= 4.007\ngini = 0.484\nsamples = 9173\nvalue = [3759, 5414]'),
#  Text(125.68242936790637, 507.8368421052632, 'X[5] <= 20.5\ngini = 0.491\nsamples = 2724\nvalue = [1548, 1176]'),
#  Text(88.18248744441249, 493.5315789473684, 'X[9] <= 21250.5\ngini = 0.497\nsamples = 2360\nvalue = [1268, 1092]'),
#  Text(55.81168831168831, 479.2263157894737, 'X[1] <= 0.5\ngini = 0.484\nsamples = 1445\nvalue = [853, 592]'),
#  Text(22.213964910728112, 464.92105263157896, 'X[5] <= 12.919\ngini = 0.458\nsamples = 1015\nvalue = [654, 361]'),
#  Text(7.9341135865837735, 450.61578947368423, 'X[0] <= 0.978\ngini = 0.382\nsamples = 417\nvalue = [310, 107]'),
#  Text(3.8230934312706033, 436.3105263157895, 'X[8] <= 3.5\ngini = 0.472\nsamples = 110\nvalue = [68, 42]'),
# ...

# %%
path = dt.cost_complexity_pruning_path(x_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
ccp_alphas
# Out:
# array([0.00000000e+00, 1.27825367e-05, 1.44868749e-05, ...,
#        1.51472592e-02, 3.10775497e-02, 7.00986339e-02])

# %%
clfs = []
for ccp_alpha in ccp_alphas:
    clf = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    clf.fit(x_train, y_train)
    clfs.append(clf)
print("Number of nodes in the last tree is: {} with ccp_alpha: {}".format(
      clfs[-1].tree_.node_count, ccp_alphas[-1]))
# Out:
# Number of nodes in the last tree is: 3 with ccp_alpha: 0.07009863394543814

# %%
train_scores = [clf.score(x_train, y_train) for clf in clfs]
test_scores = [clf.score(x_test, y_test) for clf in clfs]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas, train_scores, marker='o', label="train",
        drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker='o', label="test",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %%
clf = DecisionTreeClassifier(random_state=0, ccp_alpha= 0.01)
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.01, random_state=0)

# %%
pred=clf.predict(x_test)
pred1=clf.predict(x_train)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.7335071707953064

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.77      0.74      5796
#          1.0       0.75      0.70      0.72      5709
#
#     accuracy                           0.73     11505
#    macro avg       0.73      0.73      0.73     11505
# weighted avg       0.73      0.73      0.73     11505

# %%
print(classification_report(y_train, pred1))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.78      0.75      8585
#          1.0       0.76      0.70      0.73      8672
#
#     accuracy                           0.74     17257
#    macro avg       0.74      0.74      0.74     17257
# weighted avg       0.74      0.74      0.74     17257

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
tree.plot_tree(clf,filled=True)
# Out:
# [Text(446.4, 489.24, 'X[9] <= 0.625\ngini = 0.5\nsamples = 17257\nvalue = [8585, 8672]'),
#  Text(223.2, 380.52000000000004, 'gini = 0.298\nsamples = 4497\nvalue = [819, 3678]'),
#  Text(669.5999999999999, 380.52000000000004, 'X[7] <= 4.86\ngini = 0.476\nsamples = 12760\nvalue = [7766, 4994]'),
#  Text(446.4, 271.8, 'X[7] <= 3.441\ngini = 0.499\nsamples = 7058\nvalue = [3376, 3682]'),
#  Text(223.2, 163.08000000000004, 'gini = 0.359\nsamples = 1293\nvalue = [990, 303]'),
#  Text(669.5999999999999, 163.08000000000004, 'X[3] <= 0.304\ngini = 0.485\nsamples = 5765\nvalue = [2386, 3379]'),
#  Text(446.4, 54.360000000000014, 'gini = 0.429\nsamples = 3490\nvalue = [1089, 2401]'),
#  Text(892.8, 54.360000000000014, 'gini = 0.49\nsamples = 2275\nvalue = [1297, 978]'),
#  Text(892.8, 271.8, 'gini = 0.354\nsamples = 5702\nvalue = [4390, 1312]')]

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
ypred=rf.predict(x_test)
ytrain=rf.predict(x_train)
# Out:
# <ipython-input-1395-c3b4e16f89b1>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)

# %%
print('Accuracy Rf ',accuracy_score(y_test,ypred))
print('Precision Rf',precision_score(y_test,ypred))
print('Recall Rf',recall_score(y_test,ypred))
# Out:
# Accuracy Rf  0.8765754019991309
# Precision Rf 0.837557059656855
# Recall Rf 0.932037134349273

# %%
print(classification_report(y_test,ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.82      0.87      5796
#          1.0       0.84      0.93      0.88      5709
#
#     accuracy                           0.88     11505
#    macro avg       0.88      0.88      0.88     11505
# weighted avg       0.88      0.88      0.88     11505

# %%
print('Accuracy Rf ',accuracy_score(y_train,ytrain))
print('Precision Rf',precision_score(y_train,ytrain))
print('Recall Rf',recall_score(y_train,ytrain))
# Out:
# Accuracy Rf  0.9990728400069537
# Precision Rf 0.99850264915918
# Recall Rf 0.9996540590405905

# %%
print(classification_report(y_train,ytrain))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      8585
#          1.0       1.00      1.00      1.00      8672
#
#     accuracy                           1.00     17257
#    macro avg       1.00      1.00      1.00     17257
# weighted avg       1.00      1.00      1.00     17257

# %%
from scipy.stats import randint as sp_randint
from sklearn.model_selection import RandomizedSearchCV
from time import time
param_dist={'max_depth':sp_randint(1,7),
           'max_features':sp_randint(1,11),
           'min_samples_split':sp_randint(2,11),
           'n_estimators':sp_randint(1,100),
           'bootstrap':[True,False],
           'criterion':['gini','entropy']}

# %%
n_iter_search=20
random_search=RandomizedSearchCV(rf,param_distributions=param_dist,n_iter=n_iter_search,cv=5)

# %%
start=time()
random_search.fit(x_train,np.ravel(y_train))
print('Randomized search too %.2f secoonds for %d candidates''paramter settings.'%((time()-start),n_iter_search))

print(random_search.best_score_)
print(random_search.best_params_)
# Out:
# Randomized search too 50.69 secoonds for 20 candidatesparamter settings.
# 0.7646172050152222
# {'bootstrap': True, 'criterion': 'gini', 'max_depth': 6, 'max_features': 4, 'min_samples_split': 10, 'n_estimators': 95}

# %%
rf_grid_search=RandomForestClassifier(n_estimators=95,bootstrap=True,criterion='entropy', max_depth= 6, max_features= 4, min_samples_split= 10)

# %%
rf_grid_search.fit(x_train,y_train)
# Out:
# <ipython-input-1406-c2c77f0dd06c>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_grid_search.fit(x_train,y_train)
# RandomForestClassifier(criterion='entropy', max_depth=6, max_features=4,
#                        min_samples_split=10, n_estimators=95)

# %%
rf_grid_search.feature_importances_
# Out:
# array([0.01044407, 0.02713674, 0.03512899, 0.04243763, 0.02019318,
#        0.0295102 , 0.14198515, 0.16399591, 0.01232241, 0.49629922,
#        0.02054651])

# %%
x_train.columns
# Out:
# Index(['gender', 'relevent_experience', 'enrolled_university',
#        'education_level', 'major_discipline', 'experience', 'company_size',
#        'company_type', 'last_new_job', 'city_development_index',
#        'training_hours'],
#       dtype='object')

# %%
ypred1=rf_grid_search.predict(x_test)
y1pred=rf_grid_search.predict(x_train)

# %%
print('Accuracy Rf',accuracy_score(y_test,ypred1))
print('Precision Rf',precision_score(y_test,ypred1))
print('Recall Rf',recall_score(y_test,ypred))
# Out:
# Accuracy Rf 0.7677531508039983
# Precision Rf 0.7656113346160573
# Recall Rf 0.932037134349273

# %%
print(classification_report(y_test,ypred1))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.77      0.77      5796
#          1.0       0.77      0.77      0.77      5709
#
#     accuracy                           0.77     11505
#    macro avg       0.77      0.77      0.77     11505
# weighted avg       0.77      0.77      0.77     11505

# %%
print('Accuracy Rf',accuracy_score(y_train,y1pred))
print('Precision Rf',precision_score(y_train,y1pred))
print('Recall Rf',recall_score(y_train,y1pred))
# Out:
# Accuracy Rf 0.7691951092310367
# Precision Rf 0.7727114109573107
# Recall Rf 0.7660285977859779

# %%
print(classification_report(y_train,y1pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.77      0.77      8585
#          1.0       0.77      0.77      0.77      8672
#
#     accuracy                           0.77     17257
#    macro avg       0.77      0.77      0.77     17257
# weighted avg       0.77      0.77      0.77     17257

# %%
print(confusion_matrix(y_test,ypred1))
# Out:
# [[4456 1340]
#  [1332 4377]]

# %%
sns.heatmap(confusion_matrix(y_test,ypred1),annot=True)
# Out:
# <AxesSubplot:>

# %%
confusion_matrix(y_test,ypred1)
# Out:
# array([[4182, 1614],
#        [2140, 3569]], dtype=int64)

# %% [markdown]
# # Obseravtions :-

# %% [markdown]
# ### Accuracy of models :
# #### 1.Logistic Regression- 66%
# #### 2.Decision Tree- 73%
# #### 3.Random Forest- 77%
# #### Among the applied models Random forest is doing well.
# #### City Developement index is the most important feature from dataset followed by company type and company size.
